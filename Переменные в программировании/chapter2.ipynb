# %%
import pandas as pd

# %% [markdown]
# A. Меньше и больше счастья
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также уровне удовлетворения в отдельных аспектах. В рамках сбора данных для репрезентативных национальных выборок респондентов просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Некоторые переменные, доступные в данных:
#
# 'Country or region' - название страны
# 'Score' - Уровень индекса счастья
# 'GDP per capita' - Уровень ВВП на душу населения
# Какое максимальное и минимальное значение индекса счастья в 2019 году?

# %%
df=pd.read_csv('2019.csv')

# %%
print(df['Score'].max())
print(df['Score'].min())
# Out:
# 7.769
# 2.853

# %% [markdown]
# B. Средний уровень счастья
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также уровне удовлетворения в отдельных аспектах. В рамках сбора данных для репрезентативных национальных выборок респондентов просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Какой средний уровень счастья среди всех стран?
#
# Некоторые переменные, доступные в данных:
#
# 'Country or region' - название страны
# 'Score' - Уровень индекса счастья
# 'GDP per capita' - Уровень ВВП на душу населения
# Какой средний уровень счастья среди всех стран?

# %%
round(df['Score'].mean(),3)
# Out:
# 5.407

# %% [markdown]
# C. Медианный уровень
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также уровне удовлетворения в отдельных аспектах. В рамках сбора данных для репрезентативных национальных выборок респондентов просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Каков медианный уровень счастья среди всех стран?
#
# Некоторые переменные, доступные в данных:
#
# 'Country or region' - название страны
# 'Score' - Уровень индекса счастья
# 'GDP per capita' - Уровень ВВП на душу населения

# %%
round(df['Score'].median(),3)
# Out:
# 5.38

# %% [markdown]
# D. Мода среди всех стран
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также об уровне удовлетворения в отдельных аспектах. В рамках сбора данных для репрезентативных национальных выборок респондентов просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Какова мода среди всех стран?
#
# Учтите, что так как мод может быть несколько, то функция mode() возвращает массив, в котором может быть одно или несколько чисел. Мы точно знаем, что в этой задаче единственная мода. Чтобы вернуть её как число, добавьте явное указание, что вам нужен нулевой элемент из массива: df['col_name'].mode()[0].

# %%
round(df['Score'].mode()[0],3)
# Out:
# 5.208

# %% [markdown]
# E. Стандартное отклонение
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также уровне удовлетворения в отдельных аспектах. Репрезентативные национальные выборки респондентов просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Некоторые переменные, доступные в данных:
#
# 'Country or region' - название страны
# 'Score' - Уровень индекса счастья
# 'GDP per capita' - Уровень ВВП на душу населения
# Каково стандартное отклонение среди всех стран?

# %%
round(df['Score'].std(),3)
# Out:
# 1.113

# %% [markdown]
# F. Самые счастливые страны
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также уровне удовлетворения в отдельных аспектах. В рамках сбора данных для репрезентативных национальных выборок респондентов просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Некоторые переменные, доступные в данных:
#
# 'Country or region' - название страны
# 'Score' - Уровень индекса счастья
# 'GDP per capita' - Уровень ВВП на душу населения
# Найдите десять самых счастливых стран.
#
# Отсортируйте наблюдения по уровню счастья, затем выберите единственную колонку с названиями регионов и выведите первые 10 наблюдений. При выдаче значения должны быть выведены в качестве списка, используйте для этого функцию .tolist().

# %%
df.sort_values('Score',ascending=False)['Country or region'].head(10).tolist()
# Out:
# ['Finland',
#  'Denmark',
#  'Norway',
#  'Iceland',
#  'Netherlands',
#  'Switzerland',
#  'Sweden',
#  'New Zealand',
#  'Canada',
#  'Austria']

# %% [markdown]
# G. ВВП всех стран
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также уровне удовлетворения в отдельных аспектах. В рамках сбора данных для репрезентативных национальных выборок респондентов просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Некоторые переменные, доступные в данных:
#
# 'Country or region' - название страны
# 'Score' - Уровень индекса счастья
# 'GDP per capita' - Уровень ВВП на душу населения
# Подсчитайте суммарный ВВП всех стран.

# %%
df['GDP per capita'].sum()
# Out:
# 141.203

# %% [markdown]
# H. ВВП первых десяти стран
#
# Всемирный доклад ООН о счастье содержит данные об опросе людей в разных странах, в котором они оценивают свой общий уровень счастья, а также уровне удовлетворения в отдельных аспектах. В рамках сбора данных для репрезентативных национальных выборок просят ответить на ряд вопросов по шкале от нуля до десяти, где десять — это лучшая из возможных жизней, а ноль — худшая. Ответы отдельных респондентов усредняются для получения общего для страны показателя. Попробуем исследовать данные за 2019 год, чтобы лучше понять их структуру. CSV-файл доступен под названием “2019.csv”.
#
# Некоторые переменные, доступные в данных:
#
# 'Country or region' - название страны
# 'Score' - Уровень индекса счастья
# 'GDP per capita' - Уровень ВВП на душу населения
# Подсчитайте суммарный ВВП первых десяти стран.

# %%
round(df.head(10)['GDP per capita'].sum(),3)
# Out:
# 13.87
